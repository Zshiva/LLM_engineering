# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown

# %%
load_dotenv()

google_api_key = os.getenv('GOOGLE_API_KEY')
if not google_api_key:
    print("No API key was found - please be sure to add your key to the .env file, and save the file! Or you can skip the next 2 cells if you don't want to use Gemini")
elif not google_api_key.startswith("AIz"):
    print("An API key was found, but it doesn't start AIz")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
client = OpenAI(base_url=gemini_url, api_key=google_api_key)

# %%
tell_a_joke = [
    {"role": "user", "content" : "Tell a joke for a student on the journey to become an expert in LLM Engineering"},
]

# %%
response = client.chat.completions.create(
    model="gemini-2.5-flash-lite", 
    messages = tell_a_joke)
print(response.choices[0].message.content)
# Out:
# Why did the LLM engineer break up with the transformer model?
#
# Because it kept *generating* its own opinions and refused to *attend* to its feelings!

# %%
easy_puzzle = [

    { "role": "user", "content":
        "You toss 2 coins. One of them is heads. Whats the probability that the other is tails? Answer with the probability only"}
]

# %%
response = client.chat.completions.create(
    model="gemini-2.5-flash-lite", 
    messages = easy_puzzle,
    reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = client.chat.completions.create(
    model="gemini-2.5-flash", 
    messages = easy_puzzle,
    reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
hard_message = [
    {
        "role" : "user", "content":
        "Follow the instructions carefully: "
        "Take the any word you want  "
        "Remove the 3rd and 6th letters "
        "Reverse the remaining letters"
        "Convert each letter to its position in the alphabet (A=1, B=2, ..., Z=26)"
        "Add all the numbers together "
        "Show the word you choose at last"
        "Also show how you solve the word"
        "If the result is even → output 'SMART'"
        "If the result is odd → output 'GENIUS'"

    }
]

# %%
response = client.chat.completions.create(
    model="gemini-2.5-flash-lite", 
    messages = hard_message,
    reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Here's how I solved it:
#
# 1.  **Chosen Word:** COMPUTER
#
# 2.  **Remove the 3rd and 6th letters:**
#     *   The word is C O M P U T E R.
#     *   The 3rd letter is 'M'.
#     *   The 6th letter is 'T'.
#     *   Removing them leaves: C O P U E R
#
# 3.  **Reverse the remaining letters:**
#     *   The remaining letters are C O P U E R.
#     *   Reversing them gives: R E U P O C
#
# 4.  **Convert each letter to its position in the alphabet:**
#     *   R = 18
#     *   E = 5
#     *   U = 21
#     *   P = 16
#     *   O = 15
#     *   C = 3
#
# 5.  **Add all the numbers together:**
#     *   18 + 5 + 21 + 16 + 15 + 3 = 78
#
# 6.  **Determine the final output:**
#     *   The sum is 78.
#     *   78 is an **even** number.
#     *   Therefore, the output is 'SMART'.
#
# SMART
#
# The word I chose at last was: COMPUTER

# %%
response = client.chat.completions.create(
    model="gemini-2.5-flash", 
    messages = hard_message,
    reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# Let's go through the steps carefully!
#
# **Word chosen:** CHALLENGE
#
# **Step 1: Remove the 3rd and 6th letters**
# *   Original word: C H A L L E N G E
# *   3rd letter to remove: A
# *   6th letter to remove: E
# *   Letters remaining: C H L L N G E
#
# **Step 2: Reverse the remaining letters**
# *   C H L L N G E reversed becomes: E G N L L H C
#
# **Step 3: Convert each letter to its position in the alphabet**
# *   E = 5
# *   G = 7
# *   N = 14
# *   L = 12
# *   L = 12
# *   H = 8
# *   C = 3
#
# **Step 4: Add all the numbers together**
# *   5 + 7 + 14 + 12 + 12 + 8 + 3 = 61
#
# **Result:** 61
#
# Since the result (61) is odd, the output is:
#
# GENIUS
